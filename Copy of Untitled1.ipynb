# %%
#DAY1 ASSIGNMENT
#Take a multiple numbers through input and print the sum of the number.

s1 = int(input("Enter the first number :"))
s2 = int(input("Enter the second number :"))
sum = s1+s2
print(sum)
